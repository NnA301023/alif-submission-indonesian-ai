# %%
# Load libraries 
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Set styling
plt.style.use("ggplot")

# %%
# Load dataset
data = pd.read_csv("dataset/tweet.csv", usecols = ['sentimen', 'tweet'])

# %%
# Overview information dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1815 entries, 0 to 1814
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentimen  1815 non-null   object
#  1   tweet     1815 non-null   object
# dtypes: object(2)
# memory usage: 28.5+ KB

# %%
# Overview example data
data.sample(5)
# Out:
#      sentimen                                              tweet
# 1096   netral  ketika pa prabowo dan bang sandi berkampanye b...
# 100   negatif  Ketika wanita lain cerewat pada suaminya #Teri...
# 1226  positif  Prabowo janji tdk ambil gaji untuk mencontoh k...
# 57    positif  Lalu berbagai pencapaian telah berhasil tercap...
# 1441  negatif  Dalam debat @jokowi --melakukan kesalahan fata...

# %%
# Overview label distribution
def my_fmt(x):
    return '{:.2f}%\n({:.0f})'.format(x, total*x/100)

total = len(data)
v_counts = data['sentimen'].value_counts()

fig, ax = plt.subplots(figsize = (15, 10))
wdges, labels, autopct = ax.pie(v_counts, labels=v_counts.index, autopct=my_fmt, shadow=True)
plt.setp(labels, fontsize = 20)
plt.setp(autopct, fontsize = 20)
ax.set_title("Distribusi Sentiment terkait Pelaksanaan Pilpres 2019");

# %%
# TODO: Cleansing dataset 

## As usual ..

# %%
# TODO: Analisis Keyword per Sentiment by Wordcloud

## Sekedar analisis kata-kata yang muncul berdasarkan sentiment masing-masing, dengan mempertimbangkan adanya potensi kemunculan kata dgn makna non-semantik tapi tidak terdefinisi dalam list stopwords -> enrichment list stopwords

# %%
# TODO: Analisis topic per Sentiment by LDA

## Sekedar implement LDA untuk ekstraksi general topik aja, tetap perhatikan relevance metrics

# %%
# TODO: Analisis Sentiment & Topic per Cluster based on Custom Clustering -> Nama Pilihan Presiden 2019.

## Step 1:
### define nama pilihan presiden
### identifikasi chunking sentence, 
#### apabila dalam 1 content data memiliki hanya 1 "nama pilihan presiden" -> define content tsb. ke dalam cluster "nama presiden XYZ"
#### apabila dalam 1 content data memiliki lebih dari 1 "nama pilihan presiden" -> analisis lebih lanjut case tsb. untuk diambil mayoritas konteks "nama presiden XYZ"

## Step 2: 
### Menggunakan bag of words, latih setiap cluster dengan masing masing sentiment, sehingga "user" mengetahui keyword relevan terhadap "nama presiden XYZ"
### Iterasi menggunakan sentiment dan "nama presiden" masing-masing.

## Step 3:
### Pengambilan insight. (hati-hati)
